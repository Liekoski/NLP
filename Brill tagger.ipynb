# %%
import nltk
nltk.download('brown')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\smirn\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\smirn\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk.tag
from nltk.tag.brill import *
import nltk.tag.brill_trainer as bt
from nltk.corpus import brown
from nltk.tokenize import word_tokenize

# %%
Template._cleartemplates()
templates = fntbl37()
tagged_sentences = brown.tagged_sents(categories = 'news')
tagged_sentences = tagged_sentences[:]
tagger = nltk.tag.BigramTagger(tagged_sentences)
tagger = bt.BrillTaggerTrainer(tagger, templates, trace=3)
tagger = tagger.train(tagged_sentences, max_rules=250)
print(tagger.evaluate(brown.tagged_sents(categories='fiction')[:]))
# Out:
# TBL train (fast) (seqs: 4623; tokens: 100554; tpls: 37; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 365168 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# 26372637   015143  | None->NN if Pos:None@[1]
# 12621262   0  30  | None->. if Pos:NN@[-3,-2,-1]
# 11931193   0   3  | NN->AT if Word:the@[0] & Pos:NN@[1]
#  905 905   0   1  | NN->, if Word:,@[0]
#  568 598  30 338  | NN->IN if Pos:AT@[1] & Pos:NN@[2] & Word:the@[1]
#  516 574  58   2  | TO->IN if Pos:NN@[1,2]
#  427 427   0   5  | NN->CC if Word:and@[0]
#  379 379   0   0  | NN->AT if Word:a@[0]
#  359 359   0  21  | NN->IN if Word:of@[0]
#  243 243   0 118  | NN->TO if Word:to@[0]
#  242 242   0   9  | NN->IN if Word:in@[0]
#  187 187   0   0  | NN->'' if Word:''@[0]
#  163 176  13 116  | NN->VB if Pos:TO@[-1]
#  147 147   0   8  | NN->IN if Word:for@[0]
#   91  91   0   0  | NN->BEZ if Word:is@[0]
#   91  91   0  25  | NN->CS if Word:as@[0]
#   86  86   0   0  | NN->IN if Word:at@[0]
#   83  83   0   0  | NN->PPS if Word:he@[0]
#   81  81   0   0  | NN->`` if Word:``@[0]
#   77  77   0   1  | NN->PP$ if Word:his@[0]
#   76  76   0   0  | NN->BEDZ if Word:was@[0]
#   76  76   0   6  | NN->IN if Word:on@[0]
#   68  68   0  56  | NN->CS if Word:that@[0]
#   68  68   0   0  | NN->IN if Word:with@[0]
#   67  67   0   0  | NN->BE if Word:be@[0] & Pos:NN@[-1]
#   63  63   0   0  | NN->IN if Word:by@[0]
#   57  57   0   0  | NN->WPS if Word:who@[0]
#   54  54   0   0  | NN->PP$ if Word:their@[0] & Pos:NN@[1]
#   53  54   1   0  | NN->MD if Word:will@[0]
#   53  54   1   0  | IN->TO if Pos:VB@[1] & Pos:NN@[2]
#   52  52   0   0  | NN->AT if Word:an@[0] & Pos:NN@[1]
#   51  51   0   0  | NN->HVD if Word:had@[0]
#   50  50   0   0  | NN->WDT if Word:which@[0]
#   49  49   0   6  | IN->VB if Word:to@[-1]
#   48  50   2   0  | CS->QL if Word:as@[1,2,3]
#   48  53   5  21  | NN->VBN if Word:be@[-1]
#   47  47   0   0  | NN->* if Word:not@[0]
#   47  47   0  29  | NN->PPS if Word:it@[0]
#   46  46   0   0  | NN->IN if Word:from@[0]
#   46  46   0   0  | NN->PPSS if Word:they@[0]
#   45  45   0   0  | NN->DT if Word:this@[0]
#   44  44   0   1  | NN->VBD if Word:said@[0]
#   43  43   0   0  | NN->-- if Word:--@[0]
#   40  40   0   0  | NN->AP if Word:last@[0] & Pos:NN@[1]
#   38  38   0   0  | NN->BED if Word:were@[0]
#   37  37   0   0  | NN->CC if Word:but@[0]
#   36  36   0   0  | NN->) if Word:)@[0]
#   36  36   0   0  | NN->HVZ if Word:has@[0]
#   35  35   0   0  | NN->BER if Word:are@[0]
#   34  34   0   0  | NN->BEN if Word:been@[0]
#   32  32   0   2  | NN->CD if Word:one@[0]
#   32  32   0   0  | NN->HV if Word:have@[0]
#   31  31   0   0  | IN->CC if Word:and@[0] & Word:the@[1]
#   30  30   0   1  | NN->ABN if Word:all@[0]
#   30  30   0   0  | NN->MD if Word:would@[0]
#   30  30   0   1  | NN->RP if Word:up@[0]
#   30  30   0   4  | NN->VB if Pos:MD@[-1]
#   29  29   0   0  | NN->PP$ if Word:its@[0]
#   29  29   0  38  | NN->VBD if Pos:PPS@[-1]
#   28  28   0   0  | NN->AP if Word:other@[0]
#   28  28   0   0  | NN->CC if Word:or@[0]
#   26  37  11   4  | NN->NP if Word:Mrs.@[-3,-2,-1]
#   26  26   0   0  | NN->NNS if Word:years@[0]
#   26  26   0   0  | NN->PPO if Word:them@[0]
#   23  23   0   0  | NN->JJ if Word:new@[0] & Pos:NN@[1]
#   23  23   0   0  | NN->( if Word:(@[0]
#   23  23   0   4  | NN->RP if Word:out@[0]
#   22  22   0   0  | VB->BE if Word:be@[0] & Word:to@[-1]
#   22  22   0   0  | IN->CS if Word:as@[0] & Word:the@[1]
#   25  26   1   8  | NN->RB if Pos:QL@[-1] & Pos:CS@[1]
#   22  22   0   0  | NN->. if Word:;@[0] & Word:;@[1]
#   22  22   0   2  | NN->OD if Word:first@[0]
#   21  21   0   0  | NN->IN if Word:per@[0] & Pos:NN@[1]
#   21  21   0   0  | NN->JJ-TL if Word:New@[0] & Pos:NN@[1]
#   21  21   0   0  | NN->NN-TL if Word:President@[0]
#   21  22   1  11  | NN->VBN if Pos:HVD@[-1]
#   20  20   0   0  | NN->MD if Word:can@[0]
#   21  61  40 140  | NN->NP if Pos:,@[-1] & Pos:NN@[1]
#   20  20   0   0  | NN->PPO if Word:him@[0]
#   20  74  54 186  | NN->NP if Word:to@[-1]
#   19  20   1   6  | NN->NP-TL if Word:New@[-1]
#   18  18   0   0  | NN->PPSS if Word:I@[0]
#   17  17   0   0  | IN->CS if Word:that@[0] & Word:the@[1]
#   17  19   2   5  | NN->NP if Word:Dr.@[-3,-2,-1]
#   18  31  13  25  | NN->VBN if Word:was@[-1]
#   17  17   0   2  | NN->NP if Word:James@[-3,-2,-1]
#   17  17   0   9  | NN->AP if Word:more@[0]
#   17  17   0   0  | NN->CD if Word:two@[0]
#   17  17   0  13  | NN->CS if Word:than@[0]
#   17  17   0   0  | NN->NNS if Word:members@[0]
#   17  17   0   0  | NN->WDT if Word:what@[0]
#   17  17   0  16  | NN->VBD if Word:who@[-1]
#   16  16   0   0  | NN->NP if Word:Mrs.@[0] & Pos:NP@[1]
#   16  16   0   0  | NN->: if Word::@[0]
#   16  16   0   2  | NN->IN if Word:against@[0]
#   16  16   0   0  | NN->NNS if Word:people@[0]
#   15  18   3   0  | IN->RP if Word:in@[0] & Pos:IN@[1]
#   15  15   0   0  | NN->CS if Word:if@[0]
#   15  15   0   0  | NN->IN if Word:into@[0]
#   15  17   2  14  | NN->VBN if Word:been@[-1]
#   14  14   0   0  | NN->. if Word:?@[0] & Word:?@[1]
#   14  14   0   3  | NN->NP if Word:John@[-2,-1]
#   14  15   1   1  | CS->WPS if Word:that@[0] & Pos:MD@[1]
#   14  14   0   0  | NN->PP$ if Word:our@[0] & Pos:NN@[1]
#   14  14   0   0  | NN->VBN-TL if Word:United@[0] & Pos:NN@[1]
#   14  14   0   0  | TO->IN if Word:to@[0] & Pos:AT@[1]
#   14  14   0   0  | NN->AT if Word:no@[0]
#   14  14   0   1  | NN->JJ if Word:own@[0]
#   14  14   0   0  | NN->NR if Word:yesterday@[0]
#   14  14   0   3  | NN->NP if Word:Mr.@[-1]
#   13  13   0   0  | NN->DTI if Word:any@[0]
#   13  13   0   0  | NN->NN-TL if Word:University@[0]
#   13  13   0   0  | NN->NR if Word:today@[0]
#   13  13   0   0  | NN->PPS if Word:she@[0]
#   13  13   0   0  | NN->RB if Word:here@[0]
#   13  20   7   7  | NN->MD if Word:be@[1]
#   12  12   0   1  | NN->CD if Word:cent@[1,2]
#   12  12   0   0  | NN->BEG if Word:being@[0]
#   12  12   0   0  | NN->CD if Word:four@[0]
#   12  12   0   0  | NN->CD if Word:three@[0]
#   12  12   0   0  | NN->DTI if Word:some@[0]
#   12  12   0   0  | NN->IN if Word:without@[0]
#   12  14   2   0  | NN->JJ if Word:good@[0]
#   12  12   0   0  | NN->NP if Word:Mr.@[0]
#   12  12   0   0  | NN->NR if Word:Monday@[0]
#   12  12   0   0  | NN->WRB if Word:where@[0]
#   12  12   0   0  | NN->VBN if Word:being@[-1]
#   12  12   0   1  | IN->NN if Pos:AT@[-1] & Pos:AT@[1]
#   12  12   0  22  | NN->VB if Pos:PPSS@[-1]
#   11  14   3  10  | NN->NP if Word:President@[-2,-1]
#   11  12   1   0  | JJ->ABL if Word:such@[0] & Pos:AT@[1]
#   11  11   0   0  | NN->JJ-TL if Word:National@[0] & Pos:NN@[1]
#   11  11   0   3  | NN->EX if Word:there@[0]
#   11  11   0   7  | NN->IN if Word:after@[0]
#   11  12   1   0  | NN->NN-TL if Word:City@[0]
#   11  11   0   0  | NN->NN-TL if Word:League@[0]
#   11  11   0   0  | NN->NNS if Word:children@[0]
#   11  11   0   2  | NN->NP if Word:U.S.@[0]
#   11  11   0   0  | NN->PPSS if Word:we@[0]
#   11  11   0   0  | NN->RB if Word:also@[0]
#   11  11   0   6  | NN->VBD if Word:made@[0]
#   11  11   0   3  | NN->NNS-TL if Word:United@[-1]
#   11  14   3   1  | NN->VBN if Word:has@[-1]
#   11  11   0   3  | NN->NP if Pos:,@[-1] & Pos:VBD@[1]
#   11  11   0   0  | NP-TL->NP if Pos:AT@[-1] & Pos:NN@[1]
#   10  55  45  42  | CS->DT if Word:that@[0] & Pos:NN@[1]
#   22  35  13  21  | DT->WPS if Word:that@[0] & Pos:NN@[-1]
#   10  10   0   1  | NN->CS if Word:because@[0]
#   10  10   0   0  | NN->DT if Word:each@[0]
#   10  10   0   5  | NN->IN if Word:about@[0]
#   10  10   0   0  | NN->NR if Word:Saturday@[0]
#   10  10   0   4  | NN->PP$ if Word:her@[0]
#   10  10   0   0  | NN->RB if Word:now@[0]
#   10  11   1   3  | IN->VB if Pos:MD@[-1] & Pos:AT@[1]
#    9  11   2   0  | CS->IN if Word:than@[0] & Word:more@[-1]
#    9   9   0   0  | PPO->PPS if Word:it@[0] & Word:said@[-1]
#    9   9   0   4  | CS->WPS if Word:that@[0] & Word:is@[1]
#    9   9   0   0  | IN->TO if Word:to@[0] & Word:be@[1]
#    9   9   0   0  | IN->TO if Word:to@[0] & Word:the@[2]
#    9   9   0   1  | NN->CD if Word:p.m.@[1,2]
#    9   9   0   0  | NN->NP if Word:Chairman@[-2,-1]
#    9   9   0   0  | IN-TL->IN if Word:of@[0] & Pos:NN@[1]
#    9   9   0   3  | NN->JJ if Word:past@[0] & Pos:NN@[1]
#    9   9   0   0  | NN->QL if Word:too@[0] & Pos:NN@[1]
#    9   9   0   0  | NN->RB if Word:p.m.@[0] & Pos:CD@[-1]
#    9   9   0   0  | NN->DTS if Word:those@[0]
#    9   9   0   6  | NN->IN if Word:over@[0]
#    9   9   0   5  | NN->JJ if Word:American@[0]
#    9   9   0   0  | NN->JJ if Word:possible@[0]
#    9   9   0   1  | NN->NN-TL if Word:Dr.@[0]
#    9   9   0   1  | NN->NP if Word:Dallas@[0]
#    9   9   0   0  | NN->NR if Word:Sunday@[0]
#    9   9   0   0  | NN->RB if Word:again@[0]
#    9   9   0   0  | NN->RB if Word:then@[0]
#    8   8   0   0  | NN->NP if Word:Robert@[-2,-1]
#    8  10   2   3  | NN->NP-TL if Word:North@[-2,-1]
#    8   9   1   9  | NN->VB if Word:can@[-2,-1]
#    8   8   0   0  | NN->AT if Word:every@[0] & Pos:NN@[1]
#    8   8   0   0  | NN->JJ if Word:general@[0] & Pos:NN@[1]
#    8   8   0   0  | NN->JJ-TL if Word:Democratic@[0] & Pos:NN@[1]
#    8   8   0   0  | WPS->CS if Word:that@[0] & Pos:AT@[1]
#    8   8   0   0  | NN->NN-TL if Word:Committee@[0] & Pos:NN@[-1]
#    8   9   1   0  | PPS->PPO if Word:it@[0] & Pos:IN@[-1]
#   10  10   0   0  | IN->CS if Pos:PPS@[1]
#    8   8   0   0  | .->: if Word::@[0]
#    8   8   0   0  | NN->CD if Word:10@[0]
#    8   8   0   0  | NN->CD if Word:1960@[0]
#    8   8   0   0  | NN->CD if Word:million@[0]
#    8   8   0   1  | NN->JJ if Word:big@[0]
#    8   8   0   2  | NN->JJ if Word:such@[0]
#    8   8   0   0  | NN->NN-TL if Word:Church@[0]
#    8   8   0   0  | NN->NN-TL if Word:Senate@[0]
#    8   8   0   0  | NN->NNS if Word:laws@[0]
#    8   8   0   0  | NN->NNS if Word:men@[0]
#    8   8   0   0  | NN->NNS if Word:persons@[0]
#    8   8   0   0  | NN->NNS if Word:schools@[0]
#    8   8   0   0  | NN->NR if Word:Tuesday@[0]
#    8   8   0   0  | NN->PPLS if Word:themselves@[0]
#    8   8   0   0  | NN->RB if Word:ago@[0]
#    8   8   0   0  | NN->RB if Word:still@[0]
#    8   8   0   0  | NN->WRB if Word:when@[0]
#    8  10   2  12  | NN->VB if Word:not@[-1]
#    8  11   3  11  | NN->VBN if Word:were@[-1]
#    7   7   0   0  | NN->AP if Word:same@[0] & Word:the@[-1]
#    7   7   0   0  | CS->WPS if Word:that@[0] & Word:has@[1]
#    7   7   0   0  | IN->-- if Word:--@[0] & Word:the@[1]
#    7   7   0   0  | IN->WDT if Word:which@[0] & Word:the@[1]
#    8   9   1   0  | IN->RP if Word:on@[0] & Pos:IN@[1]
#    7   7   0   0  | NN->NP if Word:George@[-2,-1]
#    7   7   0   0  | NN->NP if Word:W.@[-2,-1]
#    7   7   0   8  | NN->VB if Word:could@[-2,-1]
#    8   8   0   0  | VB->DO if Word:do@[0]
#    7   7   0   0  | NN->NP if Word:Jr.@[1,2,3]
#    7   8   1   0  | IN->RB if Word:about@[0] & Pos:CD@[1]
#    7   7   0   0  | NN->JJ if Word:federal@[0] & Pos:NN@[1]
#    7   7   0   0  | NN->JJ if Word:private@[0] & Pos:NN@[1]
#    7   7   0   0  | NN->JJ-TL if Word:North@[0] & Pos:NP-TL@[1]
#    7   7   0   0  | NN->NN-TL if Word:Communist@[0] & Pos:NN@[1]
#    7   7   0   0  | NN->PP$ if Word:my@[0] & Pos:NN@[1]
#    7   7   0   0  | NN->NN-TL if Word:Service@[0] & Pos:NN@[-1]
#    7   7   0   0  | NN->' if Word:'@[0]
#    7   7   0   0  | NN->AP if Word:few@[0]
#    7   7   0   1  | NN->CD if Word:1@[0]
#    7   7   0   0  | NN->CD if Word:1961@[0]
#    7   7   0   0  | NN->DOD if Word:did@[0]
#    7   7   0   0  | NN->IN if Word:through@[0]
#    7   7   0   0  | NN->JJ if Word:anti-trust@[0]
#    7   7   0   0  | NN->JJ if Word:certain@[0]
#    7   7   0   0  | NN->JJ if Word:medical@[0]
#    7   7   0   0  | NN->JJ if Word:necessary@[0]
#    7   7   0   0  | NN->NN-TL if Word:Club@[0]
#    7   7   0   0  | NN->NN-TL if Word:Coast@[0]
#    7   8   1   0  | NN->NN-TL if Word:Council@[0]
#    8  12   4  15  | NN->NP if Pos:IN@[-1] & Pos:NN-TL@[-2]
#    7   7   0   0  | NN->NN-TL if Word:County@[0]
#    7   7   0   0  | NN->NN-TL if Word:House@[0]
#    7   7   0   2  | NN->NN-TL if Word:St.@[0]
#    8   8   0  11  | NN->NP-TL if Pos:NN-TL@[1] & Pos:NN@[2]
#    7   7   0   0  | NN->NNS if Word:sales@[0]
#    7   7   0   0  | NN->NNS if Word:yards@[0]
#    7   7   0   3  | NN->NP if Word:Chicago@[0]
#    7   7   0   0  | NN->RB if Word:ever@[0]
#    7   7   0   3  | NN->JJ if Word:too@[-1]
#    7  11   4   0  | NN->NP if Pos:NP@[1] & Pos:,@[2]
#    6   6   0   0  | IN->RP if Word:in@[0] & Word:bring@[-1]
#    6   6   0   0  | IN->BEDZ if Word:was@[0] & Word:the@[1]
#    6   6   0   0  | IN->WRB if Word:when@[0] & Word:the@[1]
#    6   6   0   0  | JJ->JJ-TL if Word:American@[0] & Word:League@[1]
#    6   6   0   0  | RB->IN if Word:around@[0] & Word:the@[1]
#    6   6   0   0  | NP->NP-TL if Word:University@[1,2]
# C:\Users\smirn\AppData\Local\Temp\ipykernel_12440\2311187776.py:8: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(tagger.evaluate(brown.tagged_sents(categories='fiction')[:]))
# 0.7058024763462213

# %%
print(tagger.tag(nltk.word_tokenize("You shall know a word by the company it keeps.")))
# Out:
# [('You', 'PPSS'), ('shall', 'MD'), ('know', 'VB'), ('a', 'AT'), ('word', 'NN'), ('by', 'IN'), ('the', 'AT'), ('company', 'NN'), ('it', 'PPS'), ('keeps', 'VBD'), ('.', '.')]

# %% [markdown]
# # Для русского

# %%
tagged_sents, tagged_sent = [], []

with open("GSD_train.txt", "r", encoding="utf-8") as f:
    for line in f:
        line = line.split("\t")
        if len(line) > 1:
            tagged_sent.append((line[1], line[3]))
        else:
            tagged_sents.append(tagged_sent)
            tagged_sent = []
            continue

#print(tagged_sents)

# %%
Template._cleartemplates()
templates = fntbl37()
tagged_sents = tagged_sents[:]
tagger_ru = nltk.tag.BigramTagger(tagged_sents)
tagger_ru = bt.BrillTaggerTrainer(tagger_ru, templates, trace=3)
tagger_ru = tagger_ru.train(tagged_sents, max_rules=250)
# Out:
# TBL train (fast) (seqs: 4974; tokens: 96949; tpls: 37; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 185002 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# 22702270   05552  | None->NOUN if Pos:None@[1]
#  655 655   0   0  | NOUN->PUNCT if Word:,@[0] & Pos:NOUN@[1]
#  592 592   0   3  | None->PUNCT if Pos:NOUN@[-1]
#  222 222   0  15  | NOUN->CCONJ if Word:и@[0]
#  218 218   0   0  | NOUN->ADP if Word:в@[0] & Pos:NOUN@[1]
#  138 138   0   0  | NOUN->PUNCT if Word:)@[0]
#   91  91   0   0  | NOUN->PUNCT if Word:--@[0]
#   90  90   0   0  | NOUN->PUNCT if Word:&#39;&#39;@[0]
#   83  83   0   0  | NOUN->PUNCT if Word:(@[0]
#   81  81   0   0  | NOUN->ADP if Word:на@[0] & Pos:NOUN@[1]
#   80  80   0   0  | NOUN->PUNCT if Word:``@[0]
#   70  70   0   0  | NOUN->ADP if Word:с@[0] & Pos:NOUN@[1]
#   68  80  12   5  | PRON->DET if Pos:NOUN@[1] & Pos:NOUN@[2]
#   59  59   0   0  | NOUN->PART if Word:не@[0] & Pos:NOUN@[1]
#   50  50   0   0  | NOUN->ADP if Word:к@[0] & Pos:NOUN@[1]
#   41  41   0   0  | NOUN->CCONJ if Word:а@[0]
#   41  47   6   2  | NOUN->ADJ if Word:года@[1]
#   39  39   0   0  | NOUN->ADP if Word:по@[0] & Pos:NOUN@[1]
#   36  36   0   0  | DET->PRON if Pos:PUNCT@[1] & Pos:SCONJ@[2]
#   31  31   0   0  | NOUN->PUNCT if Word:-@[0]
#   28  28   0   0  | NOUN->ADP if Word:для@[0] & Pos:NOUN@[1]
#   28  28   0   0  | NOUN->ADP if Word:от@[0] & Pos:NOUN@[1]
#   27  37  10  20  | NOUN->VERB if Word:не@[-1]
#   27  37  10   0  | AUX->VERB if Pos:NOUN@[1] & Pos:NOUN@[2]
#   23  23   0   0  | NOUN->ADP if Word:из@[0]
#   21  21   0   0  | NOUN->ADP if Word:за@[0] & Pos:NOUN@[1]
#   19  19   0  10  | NOUN->SCONJ if Word:что@[0] & Pos:NOUN@[1]
#   19  19   0   0  | NOUN->PUNCT if Word::@[0]
#   18  18   0   0  | NOUN->AUX if Word:был@[0] & Pos:NOUN@[1]
#   17  17   0   0  | NOUN->AUX if Word:было@[0] & Pos:NOUN@[1]
#   17  17   0   0  | NOUN->ADP if Word:до@[0]
#   16  16   0   0  | NUM->ADJ if Word:сентября@[1,2]
#   16  18   2   0  | CCONJ->PART if Pos:VERB@[-1] & Pos:NOUN@[1]
#   15  15   0   0  | NOUN->ADP if Word:о@[0]
#   14  14   0   0  | NOUN->CCONJ if Word:но@[0] & Word:,@[-1]
#   14  14   0  10  | NOUN->ADP if Word:как@[0]
#   14  14   0   0  | NOUN->CCONJ if Word:или@[0]
#   13  13   0   0  | NOUN->ADP if Word:во@[0] & Pos:NOUN@[1]
#   13  13   0   3  | NOUN->DET if Word:её@[0] & Pos:NOUN@[1]
#   13  13   0   0  | NOUN->PUNCT if Word:;@[0]
#   12  12   0   0  | NOUN->PRON if Word:он@[0]
#   12  17   5   6  | NOUN->VERB if Pos:AUX@[-1] & Pos:NOUN@[1]
#   11  11   0   0  | NOUN->VERB if Word:есть@[0] & Word:то@[-1]
#   11  11   0   0  | NOUN->ADP if Word:при@[0] & Pos:NOUN@[1]
#   11  16   5   0  | PRON->DET if Word:его@[0] & Pos:NOUN@[1]
#   10  10   0   0  | NOUN->SCONJ if Word:чтобы@[0] & Word:,@[-1]
#   10  12   2   0  | ADJ->NUM if Word:км@[1,2]
#   10  10   0   0  | NOUN->PRON if Word:который@[0] & Pos:NOUN@[1]
#   12  12   0   1  | NOUN->VERB if Pos:PRON@[-1] & Pos:NOUN@[1]
#   10  10   0   0  | NOUN->SYM if Word:%@[0]
#   10  10   0   1  | NOUN->ADJ if Word:году@[1]
#   10  14   4   0  | CCONJ->PART if Pos:ADV@[-1] & Pos:NOUN@[1]
#    9   9   0   0  | NOUN->ADP if Word:у@[0] & Pos:NOUN@[1]
#    9   9   0   5  | NOUN->DET if Word:его@[0] & Pos:NOUN@[1]
#    9   9   0   1  | NOUN->DET if Word:их@[0] & Pos:NOUN@[1]
#    9   9   0   0  | NOUN->PRON if Word:которые@[0]
#    9  11   2   0  | NOUN->NUM if Word:лет@[1]
#    9   9   0   0  | PRON->DET if Pos:PART@[1] & Pos:NOUN@[2] & Word:же@[1]
#    8   8   0   0  | ADV->PRON if Word:то@[0] & Word:есть@[1]
#    8   8   0   3  | NOUN->CCONJ if Word:также@[0] & Pos:PUNCT@[-2]
#    8   8   0   0  | NOUN->PROPN if Word:США@[0] & Pos:NOUN@[-2]
#    8   8   0   0  | NOUN->ADP if Word:под@[0] & Pos:NOUN@[1]
#    8   8   0   0  | NOUN->ADP if Word:через@[0] & Pos:NOUN@[1]
#    8   8   0   1  | NOUN->AUX if Word:были@[0] & Pos:NOUN@[1]
#    8   8   0   0  | NOUN->PART if Word:же@[0] & Pos:NOUN@[-1]
#    8   8   0   0  | NOUN->ADV if Word:более@[0]
#    8   8   0   9  | NOUN->ADV if Word:так@[0]
#    8   8   0   2  | NOUN->PRON if Word:это@[0]
#    8   8   0   0  | NOUN->SCONJ if Word:чем@[0]
#    8   8   0   0  | NOUN->NUM if Word:%@[1]
#    7   7   0   0  | NUM->ADJ if Word:июня@[1,2]
#    7   7   0   0  | NOUN->ADP if Word:со@[0] & Pos:NOUN@[1]
#    7   7   0   0  | NOUN->AUX if Word:была@[0] & Pos:NOUN@[1]
#    7   7   0   0  | NOUN->DET if Word:свой@[0] & Pos:NOUN@[1]
#    7   7   0   1  | SCONJ->ADV if Word:так@[0] & Pos:PART@[1]
#    7   7   0   0  | NOUN->ADP if Word:около@[0]
#    7   7   0   0  | NOUN->PRON if Word:которое@[0]
#    9  12   3   5  | NOUN->VERB if Pos:PRON@[-1] & Pos:PUNCT@[-2]
#    7   8   1   1  | NOUN->ADJ if Word:сентября@[-1]
#    6   6   0   0  | NOUN->CCONJ if Word:однако@[0] & Word:,@[-1]
#    6   6   0   0  | NOUN->ADJ if Word:деятель@[1,2]
#    6   6   0   0  | NOUN->ADJ if Word:образование@[1,2]
#    6   6   0   0  | NUM->ADJ if Word:апреля@[1,2]
#    6   6   0   0  | NUM->ADJ if Word:декабря@[1,2]
#    6   6   0   0  | NUM->ADJ if Word:марта@[1,2]
#    6   6   0   0  | NUM->ADJ if Word:февраля@[1,2]
#    6   6   0   0  | NUM->ADJ if Word:июля@[1,2,3]
#    6   6   0   0  | NOUN->X if Word:All@[-3,-2,-1]
#    6   6   0   0  | NOUN->ADV if Word:когда@[0] & Pos:NOUN@[1]
#    6   9   3   3  | ADP->ADV if Word:как@[0] & Pos:ADV@[-1]
#    6   6   0   0  | NOUN->ADV if Word:вместе@[0]
#    6   6   0   0  | NOUN->ADV if Word:уже@[0]
#    6   6   0   0  | NOUN->NUM if Word:10@[0]
#    6   6   0   0  | NOUN->PRON if Word:которой@[0]
#    6   6   0   0  | NOUN->PRON if Word:она@[0]
#    6   6   0  10  | NOUN->PRON if Word:то@[0]
#    6   6   0   0  | NOUN->ADJ if Word:декабря@[-1]
#    6   6   0   0  | NOUN->ADJ if Word:марта@[-1]
#    5   5   0   0  | NOUN->ADV if Word:т.@[-1] & Word:д@[0] & Word:.@[1]
#    5   6   1   0  | PART->CCONJ if Word:и@[0] & Word:так@[-1]
#    5   6   1   2  | PART->PRON if Word:это@[0] & Word:,@[-1]
#    5   5   0   0  | NOUN->PRON if Word:которых@[0] & Word:,@[-2]
#    5   5   0   0  | NOUN->ADJ if Word:призёр@[1,2]
#    5   5   0   0  | NUM->ADJ if Word:августа@[1,2]
#    5   5   0   0  | NUM->ADJ if Word:мая@[1,2]
#    5   6   1   0  | NUM->ADJ if Word:октября@[1,2]
#    5   5   0   0  | NUM->ADJ if Word:января@[1,2]
#    5   5   0   2  | NOUN->PROPN if Word:князя@[-2,-1]
#    5   6   1   0  | NOUN->ADJ if Word:годах@[1,2,3]
#    5   5   0   0  | NUM->ADJ if Word:ноября@[1,2,3]
#    5   5   0   1  | NOUN->PRON if Word:том@[0] & Pos:NOUN@[-2]
#    5   5   0   0  | AUX->VERB if Word:быть@[0] & Pos:NOUN@[1]
#    5   5   0   0  | NOUN->ADJ if Word:различных@[0] & Pos:NOUN@[1]
#    5   5   0   1  | NOUN->DET if Word:все@[0] & Pos:NOUN@[1]
#    5   5   0   1  | NOUN->DET if Word:всех@[0] & Pos:NOUN@[1]
#    5   5   0   1  | NOUN->NUM if Word:2@[0]
#    5   5   0   0  | NOUN->PRON if Word:этом@[0]
#    5  11   6   6  | NOUN->VERB if Pos:PRON@[-1] & Pos:NOUN@[1]
#    4   4   0   0  | PRON->ADV if Word:т.@[0] & Word:д@[1] & Word:.@[2]
#    4   4   0   0  | CCONJ->PART if Word:так@[-1] & Word:и@[0] & Word:не@[1]
#    4   4   0   1  | ADP->ADV if Word:как@[0] & Word:время@[-1]
#    4   4   0   0  | ADV->SCONJ if Word:Так@[0] & Word:как@[1]
#    4   4   0   0  | NOUN->VERB if Word:привело@[0] & Word:к@[1]
#    4   5   1   0  | NOUN->ADJ if Word:театре@[1,2]
#    4   4   0   0  | NOUN->PROPN if Word:Квинтилиан@[1,2]
#    4   4   0   0  | NOUN->X if Word:Ye@[1,2]
#    4   4   0   0  | NOUN->PROPN if Word:штабс-капитана@[-2,-1]
#    4   5   1   0  | NOUN->PROPN if Word:Юрий@[-3,-2,-1]
#    4   4   0   0  | DET->PRON if Word:собой@[0] & Pos:NOUN@[2]
#    4   4   0   0  | NOUN->ADJ if Word:новые@[0] & Pos:NOUN@[2]
#    4   4   0   0  | NOUN->ADV if Word:чаще@[0] & Pos:NOUN@[2]
#    4   4   0   0  | NOUN->DET if Word:свои@[0] & Pos:NOUN@[2]
#    4   4   0   0  | NOUN->PRON if Word:они@[0] & Pos:NOUN@[2]
#    4   4   0   0  | NOUN->ADJ if Word:танковая@[0] & Pos:NOUN@[1]
#    4   4   0   0  | NOUN->ADP if Word:без@[0] & Pos:NOUN@[1]
#    4   4   0   0  | NOUN->ADP if Word:из-за@[0] & Pos:NOUN@[1]
#    4   4   0   0  | NOUN->DET if Word:своей@[0] & Pos:NOUN@[1]
#    4   4   0   0  | NOUN->DET if Word:этого@[0] & Pos:NOUN@[1]
#    4   4   0   2  | NOUN->NUM if Word:5@[0] & Pos:NOUN@[1]
#    4   4   0   0  | NOUN->PART if Word:также@[0] & Pos:NOUN@[1]
#    4   4   0   0  | NOUN->PUNCT if Word:.@[0] & Pos:PUNCT@[1]
#    4   4   0   0  | NOUN->VERB if Word:занять@[0] & Pos:NOUN@[1]
#    4   4   0   0  | NOUN->PART if Word:только@[0] & Pos:NOUN@[-1]
#    4   4   0   0  | NOUN->PROPN if Word:РСФСР@[0] & Pos:NOUN@[-1]
#    4   4   0   0  | NOUN->ADP if Word:между@[0]
#    4   4   0   0  | NOUN->ADP if Word:среди@[0]
#    4   4   0   0  | NOUN->ADV if Word:ещё@[0]
#    4   4   0   1  | NOUN->AUX if Word:быть@[0]
#    4   4   0   0  | NOUN->DET if Word:те@[0]
#    4   4   0   0  | NOUN->NUM if Word:несколько@[0]
#    4   4   0   3  | NOUN->PART if Word:ни@[0]
#    4   4   0   0  | NOUN->PRON if Word:ей@[0]
#    4   4   0   2  | NOUN->PRON if Word:тем@[0]
#    4   4   0   0  | NOUN->SCONJ if Word:если@[0]
#    4   4   0   0  | CCONJ->X if Word:-@[1]
#    4   4   0   1  | NOUN->ADJ if Word:время@[1]
#    4   4   0   0  | NOUN->ADJ if Word:годов@[1]
#    4   4   0   0  | NOUN->ADJ if Word:область@[1]
#    4   4   0   0  | NOUN->ADJ if Word:июня@[-1]
#    4   5   1   0  | DET->PRON if Pos:NOUN@[-1] & Pos:ADP@[1]
#    4   4   0   0  | SYM->PUNCT if Pos:X@[-1] & Pos:NOUN@[1]
#    4   4   0   0  | NOUN->ADJ if Pos:NOUN@[1] & Pos:ADJ@[2] & Word:марта@[1]
#    3   5   2   0  | CCONJ->ADV if Word:,@[-1] & Word:однако@[0] & Word:,@[1]
#    3   3   0   0  | NOUN->DET if Word:в@[-1] & Word:том@[0] & Word:числе@[1]
#    3   3   0   0  | DET->PRON if Word:это@[0] & Word:на@[-1]
#    3   3   0   0  | NOUN->ADJ if Word:французский@[0] & Word:--@[-1]
#    3   3   0   0  | NOUN->ADV if Word:где@[0] & Word:,@[-1]
#    3   3   0   0  | NOUN->DET if Word:н.@[0] & Word:до@[-1]
#    3   3   0   0  | NOUN->PROPN if Word:Париж@[0] & Word:,@[-1]
#    3   3   0   0  | NOUN->PROPN if Word:Японии@[0] & Word:в@[-1]
#    3   3   0   0  | NOUN->SYM if Word:^@[0] & Word:)@[-1]
#    3   3   0   0  | NOUN->VERB if Word:позволило@[0] & Word:что@[-1]
#    3   3   0   0  | SCONJ->ADV if Word:так@[0] & Word:(@[-1]
#    3   3   0   0  | VERB->ADV if Word:менее@[0] & Word:не@[-1]
#    3   3   0   0  | VERB->PART if Word:только@[0] & Word:не@[-1]
#    3   3   0   0  | ADJ->NUM if Word:14@[0] & Word:лет@[1]
#    3   3   0   0  | ADV->SCONJ if Word:так@[0] & Word:как@[1]
#    3   3   0   0  | NOUN->ADJ if Word:Российской@[0] & Word:Федерации@[1]
#    3   3   0   0  | NOUN->VERB if Word:отказаться@[0] & Word:от@[1]
#    3   3   0   0  | ADV->SCONJ if Word:Поэтому@[0] & Word:,@[2]
#    3   3   0   0  | NOUN->DET if Word:этой@[0] & Word:,@[2]
#    3   4   1   3  | ADP->SCONJ if Word:как@[0] & Word:того@[-2]
#    3   5   2   1  | NOUN->ADJ if Word:ноября@[1,2]
#    3   3   0   1  | NOUN->VERB if Word:диктатуру@[1,2]
#    3   3   0   0  | NOUN->X if Word:Hot@[1,2]
#    3   3   0   0  | NOUN->X if Word:and@[1,2]
#    3   3   0   1  | SCONJ->PRON if Word:позволило@[1,2]
#    3   3   0   0  | NOUN->PROPN if Word:школой@[-2,-1]
#    3   3   0   2  | NOUN->VERB if Word:оно@[-2,-1]
#    3   3   0   1  | NOUN->VERB if Word:трудно@[-2,-1]
#    3   3   0   0  | NOUN->X if Word:and@[-2,-1]
#    3   3   0   0  | DET->PRON if Word:%@[1,2,3]
#    3   3   0   0  | NOUN->ADJ if Word:Александро-Невского@[1,2,3]
#    3   4   1   2  | NOUN->ADJ if Word:комитет@[1,2,3]
#    3   3   0   0  | NOUN->ADJ if Word:самоходной@[1,2,3]
#    3   3   0   0  | NOUN->PROPN if Word:заменён@[1,2,3]
#    3   3   0   0  | NOUN->VERB if Word:задней@[1,2,3]
#    3   3   0   0  | NOUN->X if Word:Houston@[1,2,3]
#    4   5   1   0  | NOUN->X if Pos:X@[-1] & Pos:X@[-2]
#    3   3   0   0  | NOUN->X if Word:Organismus.@[1,2,3]
#    3   3   0   2  | NOUN->X if Word:P@[1,2,3]
#    3   3   0   0  | NOUN->X if Word:graeco@[1,2,3]
#    3   3   0   0  | NOUN->X if Word:Стефен@[1,2,3]
#    3   3   0   0  | NOUN->ADJ if Word:кодификаторов@[-3,-2,-1]
#    3   4   1   0  | ADP->ADV if Word:как@[0] & Pos:VERB@[2]
#    3   3   0   0  | DET->PRON if Word:себя@[0] & Pos:NOUN@[2]
#    3   3   0   0  | NOUN->ADJ if Word:национального@[0] & Pos:PUNCT@[2]
#    3   3   0   0  | NOUN->ADP if Word:имени@[0] & Pos:NOUN@[2]
#    3   3   0   0  | NOUN->AUX if Word:будет@[0] & Pos:NOUN@[2]
#    5   5   0   6  | NOUN->VERB if Pos:AUX@[-1] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->DET if Word:тех@[0] & Pos:NOUN@[2]
#    3   3   0   0  | NOUN->NUM if Word:два@[0] & Pos:PUNCT@[2]
#    3   3   0   0  | NOUN->NUM if Word:один@[0] & Pos:NOUN@[2]
#    3   3   0   0  | NOUN->PRON if Word:их@[0] & Pos:NOUN@[2]
#    3   3   0   0  | NOUN->PRON if Word:ней@[0] & Pos:NOUN@[2]
#    3   3   0   0  | NOUN->PROPN if Word:Юрий@[0] & Pos:PUNCT@[2]
#    3   3   0   0  | NOUN->VERB if Word:находится@[0] & Pos:NOUN@[2]
#    3   3   0   0  | NOUN->VERB if Word:получил@[0] & Pos:NOUN@[2]
#    3   3   0   0  | NOUN->VERB if Word:следует@[0] & Pos:NOUN@[2]
#    3   3   0   0  | PRON->DET if Word:этого@[0] & Pos:PUNCT@[2]
#    3   3   0   0  | ADJ->NUM if Word:25@[0] & Pos:NOUN@[-2]
#    3   3   0   0  | NOUN->ADJ if Word:первого@[0] & Pos:NOUN@[-2]
#    3   3   0   0  | NOUN->ADV if Word:например@[0] & Pos:NOUN@[-2]
#    3   3   0   1  | NOUN->PRON if Word:т.@[0] & Pos:NOUN@[-2]
#    3   5   2   1  | SCONJ->PRON if Word:что@[0] & Pos:PROPN@[-2]
#    5   7   2   0  | NOUN->VERB if Pos:PRON@[-1] & Pos:PUNCT@[-2]
#    3   3   0   0  | ADV->NOUN if Word:рядом@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->ADJ if Word:литературный@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->ADJ if Word:новых@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->ADJ if Word:разных@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->ADP if Word:над@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->ADP if Word:против@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->ADV if Word:очень@[0] & Pos:NOUN@[1]
#    3   3   0   2  | NOUN->NUM if Word:15@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->NUM if Word:28@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->PRON if Word:оно@[0] & Pos:VERB@[1]
#    3   3   0   0  | NOUN->VERB if Word:стала@[0] & Pos:NOUN@[1]
#    3   4   1   0  | PRON->DET if Word:её@[0] & Pos:NOUN@[1]
#    3   4   1   0  | PRON->DET if Word:их@[0] & Pos:NOUN@[1]
#    3   3   0   0  | NOUN->PRON if Word:им@[0] & Pos:NOUN@[-1]
#    3   3   0   0  | NOUN->PROPN if Word:РФ@[0] & Pos:NOUN@[-1]
#    3   3   0   0  | NOUN->ADJ if Word:большее@[0]
#    3   3   0   0  | NOUN->ADJ if Word:нужно@[0]
#    3   3   0   0  | NOUN->ADJ if Word:российский@[0]
#    3   3   0   0  | NOUN->ADV if Word:менее@[0]
#    3   3   0   0  | NOUN->ADV if Word:полностью@[0]
#    3   3   0   0  | NOUN->ADV if Word:ранее@[0]
#    3   3   0   0  | NOUN->DET if Word:такие@[0]
#    3   3   0   0  | NOUN->NUM if Word:одна@[0]
#    3   3   0   0  | NOUN->PRON if Word:её@[0]

# %% [markdown]
# # Тестирование на своих фразах

# %%
print(tagger_ru.tag(nltk.word_tokenize("Кажется, я начинаю понимать, как обстоят дела с суммаризацией.")))
# Out:
# [('Кажется', 'NOUN'), (',', 'PUNCT'), ('я', 'NOUN'), ('начинаю', 'NOUN'), ('понимать', 'NOUN'), (',', 'PUNCT'), ('как', 'ADP'), ('обстоят', 'NOUN'), ('дела', 'NOUN'), ('с', 'ADP'), ('суммаризацией', 'NOUN'), ('.', 'PUNCT')]

# %% [markdown]
# # Тестирование на тестовом GSD

# %%
correct, incorrect = 0, 0

with open("GSD_test.txt", "r", encoding="utf-8") as f:
    for line in f:
        line = line.split("\t")
        if len(line) > 1:
            token = line[1]
            gold_tag = line[3]
            model_tag = tagger_ru.tag([token])
            if gold_tag == model_tag[0][1]:
                correct += 1
                #print(gold_tag, model_tag[0][1])
            else:
                incorrect += 1

all_tokens = correct + incorrect
correct_ratio = correct / all_tokens
print("Общее число токенов - ", incorrect)
print("Доля правильно размеченных токенов от общего числа - ", correct_ratio)
# Out:
# Общее число токенов -  817
# Доля правильно размеченных токенов от общего числа -  0.2136669874879692
