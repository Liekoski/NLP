# %%
import spacy

# %% [markdown]
# Выбрать задачу, чтобы задача была такой, например указать на ошибку, берт, барт, т5, какие количественные характеристики, какая у них аккурятность, есть ли проблемы в лемматизации
# Илья Сергеевич Николаев (занимался ижорским фольклором, посмотреть статьи по диалекту)
# Дообучение моделей (тонкая настройка моделей), кот знают финские, но не знают диалекты

# %%
nlp = spacy.load("fi_core_news_sm") #попробовать не sm, поискать альтернативы и посмотреть на источники, корпусы, на которых они обучены, нужно посмотреть lg и другие

# %% [markdown]
# ПОЙТИ НА HUGGINGFACE и посмотреть на что-нибдь для финского языка

# %% [markdown]
# Лемматизация

# %%
text = "Kun minä kotoani läksin niin pilvet ne varjoili."
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# Kun kun SCONJ True
# minä minä PRON True
# kotoani kotoani VERB False
# läksin läknen ADV False
# niin niin ADV True
# pilvet pilvi NOUN False
# ne se PRON True
# varjoili varjoilla VERB False
# . . PUNCT False

# %%
text = """Kun minä kotoani läksin niin pilvet ne varjoili
Ja kaikista katkerimman kohtalon mulle maailma tarjosi
Kylän karkeloissa tulin tyttösen tuntemaan
Enkä loistetta sinisistä silmistä unhoita milloinkaan
Eikä mun ikäväni haihdu täällä outojen seurassa
Ennen kuin kukkii se orajanruusu minun hautani reunalla"""
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# Kun kun SCONJ True
# minä minä PRON True
# kotoani kotoani VERB False
# läksin läknen ADV False
# niin niin ADV True
# pilvet pilvi NOUN False
# ne se PRON True
# varjoili varjoilla VERB False
#
#
#  SPACE False
# Ja ja CCONJ True
# kaikista kaikki PRON False
# katkerimman katkerimma ADJ False
# kohtalon kohtalo NOUN False
# mulle minä PRON False
# maailma maailma NOUN False
# tarjosi tarjota VERB False
#
#
#  SPACE False
# Kylän Kylä PROPN False
# karkeloissa karkeloissa NOUN False
# tulin tulla VERB True
# tyttösen tyttönen NOUN False
# tuntemaan tuntea VERB False
#
#
#  SPACE False
# Enkä ei AUX False
# loistetta loistetta VERB False
# sinisistä sinisistä ADJ False
# silmistä silmä NOUN False
# unhoita unhoita NOUN False
# milloinkaan milloinkaan ADV False
#
#
#  SPACE False
# Eikä ei AUX True
# mun minä PRON False
# ikäväni ikäväni NOUN False
# haihdu haihtua VERB False
# täällä täällä ADV True
# outojen outo NOUN False
# seurassa seura NOUN False
#
#
#  SPACE False
# ...

# %%
text = "Sitten mä kerroin että olin kotona."
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# Sitten sitten ADV True
# mä minä PRON False
# kerroin kertoa VERB False
# että että SCONJ True
# olin olla AUX True
# kotona kotona ADV False
# . . PUNCT False

# %%
text = "NLP on malli siitä miten aivomme toimivat: miten opimme, ajattelemme, kommunikoimme, teemme päätöksiä ja motivoidumme sekä miten saadaan aikaan haluttuja muutoksia."
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# NLP NLP PROPN False
# on olla AUX True
# malli malli NOUN False
# siitä se PRON True
# miten miten ADV True
# aivomme aivo NOUN False
# toimivat toimia VERB False
# : : PUNCT False
# miten miten ADV True
# opimme optia VERB False
# , , PUNCT False
# ajattelemme ajattelemme VERB False
# , , PUNCT False
# kommunikoimme kommunikoimme NOUN False
# , , PUNCT False
# teemme tehdä VERB False
# päätöksiä päätös NOUN False
# ja ja CCONJ True
# motivoidumme motivoidua NOUN False
# sekä sekä CCONJ True
# miten miten ADV True
# saadaan saada VERB False
# aikaan aika NOUN True
# haluttuja haluta VERB False
# muutoksia muutos NOUN False
# . . PUNCT False

# %%
text = "Suomen kieli eli suomi on uralilaisten kielten itämerensuomalaiseen ryhmään kuuluva kieli, jota puhuvat pääosin suomalaiset. Suomessa suomen kieltä puhuu äidinkielenään 4,8 miljoonaa ja toisena kielenään 0,5 miljoonaa ihmistä."
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# Suomen Suomi PROPN False
# kieli kieli NOUN False
# eli eli CCONJ True
# suomi Suomi PROPN False
# on olla AUX True
# uralilaisten uralilainen ADJ False
# kielten kieli NOUN False
# itämerensuomalaiseen itämerensuomalaiseen ADJ False
# ryhmään ryhmä NOUN False
# kuuluva kuulua VERB False
# kieli kieli NOUN False
# , , PUNCT False
# jota joka PRON True
# puhuvat puhua VERB False
# pääosin pääosin ADV False
# suomalaiset suomalainen NOUN False
# . . PUNCT False
# Suomessa Suomi PROPN False
# suomen suomi NOUN False
# kieltä kieli NOUN False
# puhuu puhua VERB False
# äidinkielenään äidinkielenään NOUN False
# 4,8 4,8 NUM False
# miljoonaa miljoona NUM False
# ja ja CCONJ True
# toisena toinen ADJ False
# kielenään kielenään NOUN False
# 0,5 0,5 NUM False
# miljoonaa miljoona NUM False
# ihmistä ihminen NOUN False
# . . PUNCT False

# %%
text = "Sitten mä kerroin että olin kodissa."
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# Sitten sitten ADV True
# mä minä PRON False
# kerroin kertoa VERB False
# että että SCONJ True
# olin olla AUX True
# kodissa koti NOUN False
# . . PUNCT False

# %%
import pandas as pd

cols = ("text", "lemma", "POS", "explain", "stopword")
rows = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows.append(row)

df = pd.DataFrame(rows, columns=cols)
    
df
# Out:
#       text   lemma    POS                    explain  stopword
# 0   Sitten  sitten    ADV                     adverb      True
# 1       mä    minä   PRON                    pronoun     False
# 2  kerroin  kertoa   VERB                       verb     False
# 3     että    että  SCONJ  subordinating conjunction      True
# 4     olin    olla    AUX                  auxiliary      True
# 5  kodissa    koti   NOUN                       noun     False
# 6        .       .  PUNCT                punctuation     False

# %%
from spacy import displacy

# %%
doc = nlp("Istun nyt hahvilassa, jossa istuimme keskustelemassa eilen")

# %%
displacy.render(doc, style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fi" id="9847a775047845cda35ca0530b66786d-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Istun</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">nyt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
doc = nlp("Kissa synnytti kolme pentua: mustan, valkoisen ja harmaan")
displacy.render(doc, style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fi" id="4900fa37dc29491282fdf8650cef6989-0" class="displacy" width="1450" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Kissa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">synnytti</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %% [markdown]
# Выделяем проблемны слова из примеров выше

# %%
text = "kotoani kotona läksin ajattelemme kommunikoimme motivoidumme itämerensuomalaiseen äidinkielenään"
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# kotoani kotoani NOUN False
# kotona kotona ADV False
# läksin läknen NOUN False
# ajattelemme ajattelemme VERB False
# kommunikoimme kommunikoimme VERB False
# motivoidumme motivoidu NOUN False
# itämerensuomalaiseen itämerensuomalaiseen ADV False
# äidinkielenään äidinkielenään NOUN False

# %%
import pandas as pd

cols = ("text", "lemma", "POS", "explain", "stopword")
rows = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows.append(row)

df = pd.DataFrame(rows, columns=cols)
    
df
# Out:
#                    text                 lemma   POS explain  stopword
# 0               kotoani               kotoani  NOUN    noun     False
# 1                kotona                kotona   ADV  adverb     False
# 2                läksin                läknen  NOUN    noun     False
# 3           ajattelemme           ajattelemme  VERB    verb     False
# 4         kommunikoimme         kommunikoimme  VERB    verb     False
# 5          motivoidumme             motivoidu  NOUN    noun     False
# 6  itämerensuomalaiseen  itämerensuomalaiseen   ADV  adverb     False
# 7        äidinkielenään        äidinkielenään  NOUN    noun     False

# %%
text = "ajattelen maitse läksin kissoja kotona ulkona ulos lukea postitse huoneeseen huoneissa parvekkeeseen parvekkeella parveke omenoita omena"
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# ajattelen ajatella VERB False
# maitse maitse NOUN False
# läksin läksi NOUN False
# kissoja kissa NOUN False
# kotona kotona ADV False
# ulkona ulkona ADV False
# ulos ulos ADV False
# lukea lukea VERB False
# postitse postitse ADV False
# huoneeseen huone NOUN False
# huoneissa huone NOUN False
# parvekkeeseen parvekkeenen NOUN False
# parvekkeella parvekkeella NOUN False
# parveke parveke NOUN False
# omenoita omena AUX False
# omena omena NOUN False

# %%
import pandas as pd

cols = ("text", "lemma", "POS", "explain", "stopword")
rows = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows.append(row)

df = pd.DataFrame(rows, columns=cols)
    
df
# Out:
#              text         lemma   POS    explain  stopword
# 0       ajattelen      ajatella  VERB       verb     False
# 1          maitse        maitse  NOUN       noun     False
# 2          läksin         läksi  NOUN       noun     False
# 3         kissoja         kissa  NOUN       noun     False
# 4          kotona        kotona   ADV     adverb     False
# 5          ulkona        ulkona   ADV     adverb     False
# 6            ulos          ulos   ADV     adverb     False
# 7           lukea         lukea  VERB       verb     False
# 8        postitse      postitse   ADV     adverb     False
# 9      huoneeseen         huone  NOUN       noun     False
# 10      huoneissa         huone  NOUN       noun     False
# 11  parvekkeeseen  parvekkeenen  NOUN       noun     False
# 12   parvekkeella  parvekkeella  NOUN       noun     False
# 13        parveke       parveke  NOUN       noun     False
# 14       omenoita         omena   AUX  auxiliary     False
# ...

# %% [markdown]
# Неправильно лемматизированные слова

# %%
text = "maitse sinisistä kukkii unhoita karkeloissa katkerimman läksin kotona ulkona ulos postitse parvekkeeseen parvekkeella kotoani kotona läksin ajattelemme kommunikoimme motivoidumme itämerensuomalaiseen äidinkielenään"
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# maitse maitse ADV False
# sinisistä sinisistä NOUN False
# kukkii kukkii PRON False
# unhoita unhoi NOUN False
# karkeloissa karkeloissa NOUN False
# katkerimman katkerimma VERB False
# läksin läksi NOUN False
# kotona kotona ADV False
# ulkona ulkona ADV False
# ulos ulos ADV False
# postitse postitse ADV False
# parvekkeeseen parvekkeeseen NOUN False
# parvekkeella parveke NOUN False
# kotoani kotoani NOUN False
# kotona kotona ADV False
# läksin läknen NOUN False
# ajattelemme ajattelemme VERB False
# kommunikoimme kommunikoimme VERB False
# motivoidumme motivoidu NOUN False
# itämerensuomalaiseen itämerensuomalaiseen ADV False
# äidinkielenään äidinkielenään NOUN False

# %%
import pandas as pd

cols = ("text", "lemma", "POS", "explain", "stopword")
rows = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows.append(row)

df = pd.DataFrame(rows, columns=cols)
    
df
# Out:
#                     text                 lemma   POS  explain  stopword
# 0                 maitse                maitse   ADV   adverb     False
# 1              sinisistä             sinisistä  NOUN     noun     False
# 2                 kukkii                kukkii  PRON  pronoun     False
# 3                unhoita                 unhoi  NOUN     noun     False
# 4            karkeloissa           karkeloissa  NOUN     noun     False
# 5            katkerimman            katkerimma  VERB     verb     False
# 6                 läksin                 läksi  NOUN     noun     False
# 7                 kotona                kotona   ADV   adverb     False
# 8                 ulkona                ulkona   ADV   adverb     False
# 9                   ulos                  ulos   ADV   adverb     False
# 10              postitse              postitse   ADV   adverb     False
# 11         parvekkeeseen         parvekkeeseen  NOUN     noun     False
# ...

# %%
nlp = spacy.load("fi_core_news_lg")

# %%
text = "Kun minä kotoani läksin niin pilvet ne varjoili."
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# Kun kun SCONJ True
# minä minä PRON True
# kotoani kotoani NOUN False
# läksin läkta VERB False
# niin niin ADV True
# pilvet pilvi NOUN False
# ne se PRON True
# varjoili varjoili VERB False
# . . PUNCT False

# %%
text = """Kun minä kotoani läksin niin pilvet ne varjoili
Ja kaikista katkerimman kohtalon mulle maailma tarjosi
Kylän karkeloissa tulin tyttösen tuntemaan
Enkä loistetta sinisistä silmistä unhoita milloinkaan
Eikä mun ikäväni haihdu täällä outojen seurassa
Ennen kuin kukkii se orajanruusu minun hautani reunalla"""
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# Kun kun SCONJ True
# minä minä PRON True
# kotoani kotoani NOUN False
# läksin läkta VERB False
# niin niin ADV True
# pilvet pilvi NOUN False
# ne se PRON True
# varjoili varjoili VERB False
#
#
#  SPACE False
# Ja ja CCONJ True
# kaikista kaikki PRON False
# katkerimman katkerimman ADJ False
# kohtalon kohtalo NOUN False
# mulle minä PRON False
# maailma maailma NOUN False
# tarjosi tarjota VERB False
#
#
#  SPACE False
# Kylän Kylä PROPN False
# karkeloissa karkeloissa NOUN False
# tulin tulla VERB True
# tyttösen tyttönen NOUN False
# tuntemaan tuntea VERB False
#
#
#  SPACE False
# Enkä ei AUX False
# loistetta loiste NOUN False
# sinisistä sininen ADJ False
# silmistä silmä NOUN False
# unhoita unhoita NOUN False
# milloinkaan milloinkaan ADV False
#
#
#  SPACE False
# Eikä ei AUX True
# mun minä PRON False
# ikäväni ikävä ADV False
# haihdu haihtua VERB False
# täällä täällä ADV True
# outojen outo NOUN False
# seurassa seura NOUN False
#
#
#  SPACE False
# ...

# %%
nlp = spacy.load("fi_core_news_md")

# %%
text = "Kun minä kotoani läksin niin pilvet ne varjoili."
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# Kun kun SCONJ True
# minä minä PRON True
# kotoani kotoani NOUN False
# läksin läkta VERB False
# niin niin ADV True
# pilvet pilvi NOUN False
# ne se PRON True
# varjoili varjoilla VERB False
# . . PUNCT False

# %%
text = """Kun minä kotoani läksin niin pilvet ne varjoili
Ja kaikista katkerimman kohtalon mulle maailma tarjosi
Kylän karkeloissa tulin tyttösen tuntemaan
Enkä loistetta sinisistä silmistä unhoita milloinkaan
Eikä mun ikäväni haihdu täällä outojen seurassa
Ennen kuin kukkii se orajanruusu minun hautani reunalla"""
doc = nlp(text)

i = 0
for token in doc:
    i = i + 1
    print(token.text, token.lemma_, token.pos_, token.is_stop)
    if i == 3 or i == 4 or i == 12 or i == 19 or i == 21 or i == 24:
        print("Error here")
# Out:
# Kun kun SCONJ True
# minä minä PRON True
# kotoani kotoani NOUN False
# Error here
# läksin läkta VERB False
# Error here
# niin niin ADV True
# pilvet pilvi NOUN False
# ne se PRON True
# varjoili varjoillä VERB False
#
#
#  SPACE False
# Ja ja CCONJ True
# kaikista kaikki PRON False
# katkerimman katkerimman ADJ False
# Error here
# kohtalon kohtalo NOUN False
# mulle minä PRON False
# maailma maailma NOUN False
# tarjosi tarjota VERB False
#
#
#  SPACE False
# Kylän Kylä PROPN False
# karkeloissa karkeloa NOUN False
# Error here
# tulin tulla VERB True
# tyttösen tyttösen PROPN False
# Error here
# tuntemaan tuntea VERB False
#
#
#  SPACE False
# Enkä ei AUX False
# Error here
# loistetta loiste NOUN False
# sinisistä sininen ADJ False
# silmistä silmä NOUN False
# unhoita unhoittaa NOUN False
# milloinkaan milloinkaan ADV False
#
#
#  SPACE False
# Eikä ei AUX True
# mun minä PRON False
# ikäväni ikäväni ADV False
# haihdu haihdu ADV False
# täällä täällä ADV True
# ...
