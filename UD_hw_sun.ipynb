# %%
import conllu

# %%
from conllu import parse

# %%
#f = open('rueval_2010_goldstandard_tagged.txt', 'r')

# %% [markdown]
# Здесь я создаю файл, но текст записываю в сам код

# %%
f2 = open('rueval_2010_goldstandard_text(2).txt', 'w')

# %%
from ufal.udpipe import Model, Pipeline
model = Model.load('russian-ud-2.0-170801.udpipe') # путь к модели

# %%
example = ("""Цветки дикорастущих форм обыкновенной сирени мелкие, собраны парными пучками (по 3 - 5 цветков в пучке, отдельные сорта по 7 - 9 цветков). 
В конце осени кора побегов становится серой. 
В центре цветка бело-кремовое пятнышко в виде звездочки. 
При уплотнении почвы и асфальтировании суховершинит. 
Морозостоек. 
Родина - горные леса Тянь-Шаня. 
Дико растет на сухих склонах в умеренно теплых районах на обширной территории от Западной Европы до восточной Азии. 
Полученное количество саженцев затем распределяют пропорционально объему работ по годам перспективного периода и вычисляют среднегодовую потребность. 
Дистальнее места сужения проток не визуализируется. 
ЗАКЛЮЧЕНИЕ: Инфильтративные изменения в зоне гепатикоэнтероанастомоза, в воротах печени, во внутрибрюшной жировой клетчатке. 
Золотовалютные резервы увеличились на 170 миллиардов долларов и приближаются к отметке в полтриллиона долларов США - точнее, 478,6, по последним данным (чуть-чуть понижение произошло в связи с изменением курса доллара). 
Это вершина тесного и плодотворного сотрудничества между нашими странами. 
Мы еще некоторое время разговариваем с Епископом Лукианом, потом он провожает меня до ворот Резиденции, откуда навстречу нам идет многочисленный и многоязычный поток людей, желающих осмотреть экспонаты Православного Музея и посетить Кафедральный Собор. 
Многотысячный коллектив "Газпрома" денно и нощно трудился над поставленной задачей. 
Там оставалось еще 60 сербских сел. 
Мы шли в бой вместе и готовы были пролить кровь друг за друга. 
- Какие впечатления у вас остались от Москвы в 1972 году? 
- По удивительному стечению обстоятельств ваш олимпийский триумф идеально совпал по времени с внедрением современных поролоновых матов. 
Все поселение можно обойти неторопливым шагом за 10 минут. 
Стабильное взаимодействие в нефтегазовом секторе является общим вкладом России и Венгрии в обеспечение энергобезопасности Европы. 
При этом работа над реализаций проектов жёстко увязывалась с достижением на каждом этапе целевых показателей. 
Наверняка техника была бы уже не та. 
Я имею в виду наше сотрудничество в сфере энергетики - первый блок Сангтудинской ГЭС станции запущен в январе. 
В рамках национального проекта 13 миллионов человек смогли пройти диспансеризацию, а 60 миллионам были сделаны прививки. 
Оба работают на влиятельную и известную адвокатскую контору «Bullie Brake & Desmay» и успешно продвигаются по служебной лестнице. 
Некоторые люди испытывают панические атаки, которые характеризуются чрезвычайно сильным чувством страха. 
Они отнюдь не редки. 
К третьей неделе пациенты показывали заметное улучшение настроения в отличие от принимавших плацебо. 
Высокий уровень эстрогена и низкий прогестерона могут привести к предменструальному синдрому (ПМС) с цикличной депрессией и беспокойством. 
Иногда колебания настроения и депрессия могут быть результатом слишком большого стресса и истощения надпочечников. 
Первое описание этого члена семейства перечных появилось в западных странах после знаменитых рейдов капитана Джеймса Кука в Южные моря. 
Согласно данным Национального аутистического общества частота аутизма сейчас может превышать 1 случай на каждые 100 детей. 
Конечная цель математики — вообще избавиться от необходимости о чем-либо думать. 
В том-то и дело, что, кроме действительных чисел, достаточно изобрести только одно число — квадратный корень из —1, после этого можно решить любое алгебраическое уравнение] 
# # newpar
# # sent_id = 1
# # text = Цветки дикорастущих форм обыкновенной сирени мелкие, собраны парными пучками (по 3 - 5 цветков в пучке, отдельные сорта по 7 - 9 цветков).
# 1	Цветки	ЦВЕТОК	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur	6	nsubj	_	_
# 2	дикорастущих	дикорастущих	ADJ	JJL	Animacy=Inan|Case=Gen|Number=Plur	3	amod	_	_
# 3	форм	ФОРМА	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	1	nmod	_	_
# 4	обыкновенной	АННобыкнове	ADJ	JJL	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	5	amod	_	_
# 5	сирени	сирени	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	3	nmod	_	_
# 6	мелкие	МЕЛКИЙ	ADJ	JJL	Animacy=Anim|Case=Nom|Number=Plur	0	root	_	SpaceAfter=No
# 7	,	,	PUNCT	,	_	8	punct	_	_
# 8	собраны	СОБРАТЬ	VERB	VBNH	Animacy=Inan|Aspect=Perf|Case=Nom|Number=Plur|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	6	conj	_	_
# 9	парными	парными	ADJ	JJL	Animacy=Inan|Case=Ins|Number=Plur	10	amod	_	_
# ...

# %%
f2.write(parsed)
# Out:
# 218527

# %%
f2.close()

# %% [markdown]
# Здесь текст уже берётся из файла и делает морфемный разбор, записывая результат в новый файл

# %%
f = open('rueval_2010_goldstandard_text(1).txt', 'r')
text = f.read()
f.close()

# %%
new_f = open('goldstandart3.txt', 'w')
new_f.write(text)
new_f.close()

# %%
from ufal.udpipe import Model, Pipeline
model = Model.load('russian-ud-2.0-170801.udpipe')

# %%
#ВНИМАНИЕ! НЕ ИСПОЛЬЗУЙТЕ ЭТОТ КОД. зДЕСЬ ОШИБКА, ПЫТАЮСЬ РАЗОБРАТЬСЯ

#file = open('goldstandart3.txt', 'r+')
#file = file.readlines()
#pipeline = Pipeline(model, 'tokenize', Pipeline.DEFAULT, Pipeline.DEFAULT, Pipeline.DEFAULT)
#for line in file:
 #   parsed = pipeline.process(text)
    #ДАЛЕЕ - он раз за разом снова и снова записывает в файл
    #for word in line: 
        #with open('goldstandart3.txt', 'a') as f1:
            #f1.write(parsed)
            #f1.close()

# %% [markdown]
# Лучше слудующий

# %%
file1 = open('goldstandart4.txt', 'w+')
file1.write(parsed)
file1.close()
#в данном случае он лишь один раз записывает то, что нам нужно, поэтому этот код проще и в нём нет ошибок

# %% [markdown]
# Рисуем дерево для первого предложения

# %%
from nltk import DependencyGraph

# %%
sent = '''Цветки дикорастущих форм обыкновенной сирени мелкие, собраны парными пучками (по 3 - 5 цветков в пучке, отдельные сорта по 7 - 9 цветков). '''
parsed = pipeline.process(sent)

# костыли для dependency graph
parsed = '\n'.join([line for line in parsed.split('\n') if not line.startswith('#')])
parsed = parsed.replace('\troot\t', '\tROOT\t')

# %%
print(parsed)
# Out:
# 1	Цветки	ЦВЕТОК	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur	6	nsubj	_	_
# 2	дикорастущих	дикорастущих	ADJ	JJL	Animacy=Inan|Case=Gen|Number=Plur	3	amod	_	_
# 3	форм	ФОРМА	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	1	nmod	_	_
# 4	обыкновенной	АННобыкнове	ADJ	JJL	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	5	amod	_	_
# 5	сирени	сирени	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	3	nmod	_	_
# 6	мелкие	МЕЛКИЙ	ADJ	JJL	Animacy=Anim|Case=Nom|Number=Plur	0	ROOT	_	SpaceAfter=No
# 7	,	,	PUNCT	,	_	8	punct	_	_
# 8	собраны	СОБРАТЬ	VERB	VBNH	Animacy=Inan|Aspect=Perf|Case=Nom|Number=Plur|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	6	conj	_	_
# 9	парными	парными	ADJ	JJL	Animacy=Inan|Case=Ins|Number=Plur	10	amod	_	_
# 10	пучками	пучками	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur	8	iobj	_	_
# 11	(	(	PUNCT	(	_	16	punct	_	SpaceAfter=No
# 12	по	ПО	ADP	IN	_	16	case	_	_
# 13	3	3	ADV	AFX	_	16	nummod	_	_
# 14	-	-	PUNCT	-	_	13	goeswith	_	_
# ...

# %%
graph = DependencyGraph(tree_str=parsed)
list(graph.triples())
# Out:
# [(('мелкие', 'ADJ'), 'nsubj', ('Цветки', 'NOUN')),
#  (('Цветки', 'NOUN'), 'nmod', ('форм', 'NOUN')),
#  (('форм', 'NOUN'), 'amod', ('дикорастущих', 'ADJ')),
#  (('форм', 'NOUN'), 'nmod', ('сирени', 'NOUN')),
#  (('сирени', 'NOUN'), 'amod', ('обыкновенной', 'ADJ')),
#  (('мелкие', 'ADJ'), 'conj', ('собраны', 'VERB')),
#  (('собраны', 'VERB'), 'punct', (',', 'PUNCT')),
#  (('собраны', 'VERB'), 'iobj', ('пучками', 'NOUN')),
#  (('пучками', 'NOUN'), 'amod', ('парными', 'ADJ')),
#  (('собраны', 'VERB'), 'obl', ('цветков', 'NOUN')),
#  (('цветков', 'NOUN'), 'punct', ('(', 'PUNCT')),
#  (('цветков', 'NOUN'), 'case', ('по', 'ADP')),
#  (('цветков', 'NOUN'), 'nummod', ('3', 'ADV')),
#  (('3', 'ADV'), 'goeswith', ('-', 'PUNCT')),
#  (('3', 'ADV'), 'goeswith', ('5', 'NUM')),
#  (('цветков', 'NOUN'), 'nmod', ('пучке', 'NOUN')),
#  (('пучке', 'NOUN'), 'case', ('в', 'ADP')),
#  (('цветков', 'NOUN'), 'conj', ('сорта', 'NOUN')),
#  (('сорта', 'NOUN'), 'punct', (',', 'PUNCT')),
# ...

# %%
tree = graph.tree()
print(tree.pretty_print())
# Out:
#                                                          мелкие
#   _________________________________________________________|_______________
#  |                 |                                                    собраны
#  |                 |                   ____________________________________|_______
#  |                 |                  |     |                                   цветков
#  |                 |                  |     |      ________________________________|____________________
#  |               Цветки               |     |     |   |    |         |             |                  сорта
#  |                 |                  |     |     |   |    |         |             |      ______________|______
#  |                форм                |     |     |   |    |         |             |     |      |           цветков
#  |        _________|_________         |     |     |   |    |         |             |     |      |        ______|_____
# ...
